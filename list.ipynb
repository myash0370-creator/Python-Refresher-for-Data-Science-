# %%
l = [ 2 , 3 , 4 , 5]
l[0] = 1
l
# Out:
# [1, 3, 4, 5]

# %%
l.append(9)
l
# Out:
# [1, 3, 4, 5, 9, 9]

# %%
l2 = [10,12]
l.extend(l2)
l
# Out:
# [1, 3, 4, 5, 9, 9, 10, 12, 10, 12]

# %%
number = l.pop(5)
number
# Out:
# 10

# %%
l
# Out:
# [1, 3, 4, 5, 9, 12, 10, 12]

# %%
l.index(3)
# Out:
# 1

# %%
l.index(9)
# Out:
# 4

# %%
l.insert(1 ,2)
l
# Out:
# [1, 2, 2, 3, 4, 5, 9, 12, 10, 12]

# %%
l.sort() #replace a original list
l
# Out:
# [1, 2, 2, 3, 4, 5, 9, 10, 12, 12]

# %%
sorted(l) #make a new list
# Out:
# [1, 2, 2, 3, 4, 5, 9, 10, 12, 12]

# %%
x = [ 1,2,3,[4,5]] #nested list
x
# Out:
# [1, 2, 3, [4, 5]]

# %%
x[3]
# Out:
# [4, 5]

# %%
x[3] [1]
# Out:
# 5

# %%
list1 = [1 ,2 , 6 , 8]
list2 = [ 4 ,5 , 9 ,10]
list1 + list2
# Out:
# [1, 2, 6, 8, 4, 5, 9, 10]

# %%
4 in list2
# Out:
# True

# %%
45 in list1
# Out:
# False

# %%
s = "yash-ashish-suraj-sagar-shivel"
s.split("-")
# Out:
# ['yash', 'ashish', 'suraj', 'sagar', 'shivel']
