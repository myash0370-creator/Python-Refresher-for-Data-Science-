# %%
a = input("Enter a name: ")
# Out:
# Enter a name:  Yash Mishra

# %%
a
# Out:
# 'Yash Mishra'

# %%
b = int(input("Enter a number : "))
# Out:
# Enter a number :  18

# %%
c = input("Enter a number: ")
# Out:
# Enter a number:  19

# %%
b + int(c)
# Out:
# 37
