# %%
code = 700

# %%
match code:
    case 100:
        print("OK RESPONSE!")
    case 300:
        print("BAD RESPONSE!")
    case 500:
        print("NOT FOUND")
    case _:
        print("Nothing Matched")

print("End of Program")
# Out:
# Nothing Matched
# End of Program
