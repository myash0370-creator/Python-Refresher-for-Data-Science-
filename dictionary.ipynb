# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
# Dictionary with key-value pairs
student = {
    "name": "Alice",
    "age": 25,
    "grade": "A"
}

# %%
student["name"]
# Out:
# 'Alice'

# %%
r = student.get("name4")

# %%
print(r)
# Out:
# None

# %%
student["age"] = 21
student
# Out:
# {'name': 'Alice', 'age': 21, 'grade': 'A'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Alice', 21, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 21), ('grade', 'A')])

# %%
student.update({"name":"Yash", "grade":"A+"})
student
# Out:
# {'name': 'Yash', 'age': 21, 'grade': 'A+'}
