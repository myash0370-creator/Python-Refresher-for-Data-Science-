# %%
# using format
name = "Yash"
age = 20
print(" My name is {}, and i am {} old".format(name , age))
# Out:
#  My name is Yash, and i am 20 old

# %%
# use of f strings
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Yash and I am 20 years old.

# %%
print(f"{'Python':<10}")  # Left-align
print(f"{'Python':>10}")  # Right-align
print(f"{'Python':^10}")  # Center-align
# Out:
# Python
#     Python
#   Python
