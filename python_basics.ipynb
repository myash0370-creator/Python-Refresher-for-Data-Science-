# %%
a = 7

# %%
b = 5

# %%
print(a+b)
# Out:
# 12

# %%
print("Hello world")
# Out:
# Hello world

# %%
name = "Yash"

# %%
print(name)
# Out:
# Yash

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(b)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
a = "45"
b = "50"

# %%
print(a+b)
# Out:
# 4550

# %%
int(a) + int(b) #typecasting
# Out:
# 95
