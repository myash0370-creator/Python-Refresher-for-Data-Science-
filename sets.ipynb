# %%
a = set()

# %%
type(a)
# Out:
# set

# %%
s = {1 , 2, 3, 4 , 5 ,4,2}
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(6)
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s.update([6 ,7 ,8])
s
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s.remove(7)
s
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
s.discard(99)
s
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
set1 = {1,2,3,4}
set2 = {3,4,5,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
sub = {1,3}
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True
