# %%
name = "Yash"

# %%
name
# Out:
# 'Yash'

# %%
#methods of strings

# %%
name.upper()
# Out:
# 'YASH'

# %%
name.lower()
# Out:
# 'yash'

# %%
name.endswith("sh")
# Out:
# True

# %%
name.endswith("tu")
# Out:
# False

# %%
name.count("a")
# Out:
# 1

# %%
n = "Yash Mishra"
len(n)
# Out:
# 11

# %%
n[0:3]
# Out:
# 'Yas'

# %%
n[-1:1]
# Out:
# ''
